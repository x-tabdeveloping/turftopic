# %%
# %pip install --upgrade turftopic[pyro-ppl]
# Out:
# Collecting turftopic[pyro-ppl]
#   Downloading turftopic-0.2.0-py3-none-any.whl (21 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.23.0 in /usr/local/lib/python3.10/dist-packages (from turftopic[pyro-ppl]) (1.23.5)
# Requirement already satisfied: rich<14.0.0,>=13.6.0 in /usr/local/lib/python3.10/dist-packages (from turftopic[pyro-ppl]) (13.7.0)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from turftopic[pyro-ppl]) (1.2.2)
# Requirement already satisfied: scipy<2.0.0,>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from turftopic[pyro-ppl]) (1.11.4)
# Collecting sentence-transformers<3.0.0,>=2.2.0 (from turftopic[pyro-ppl])
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 3.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch<3.0.0,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from turftopic[pyro-ppl]) (2.1.0+cu121)
# Collecting pyro-ppl<2.0.0,>=1.8.0 (from turftopic[pyro-ppl])
#   Downloading pyro_ppl-1.8.6-py3-none-any.whl (732 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 732.8/732.8 kB 11.4 MB/s eta 0:00:00
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from pyro-ppl<2.0.0,>=1.8.0->turftopic[pyro-ppl]) (3.3.0)
# Collecting pyro-api>=0.1.1 (from pyro-ppl<2.0.0,>=1.8.0->turftopic[pyro-ppl])
#   Downloading pyro_api-0.1.2-py3-none-any.whl (11 kB)
# Requirement already satisfied: tqdm>=4.36 in /usr/local/lib/python3.10/dist-packages (from pyro-ppl<2.0.0,>=1.8.0->turftopic[pyro-ppl]) (4.66.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=13.6.0->turftopic[pyro-ppl]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=13.6.0->turftopic[pyro-ppl]) (2.16.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2.0.0,>=1.2.0->turftopic[pyro-ppl]) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2.0.0,>=1.2.0->turftopic[pyro-ppl]) (3.2.0)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers<3.0.0,>=2.2.0->turftopic[pyro-ppl]) (4.35.2)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers<3.0.0,>=2.2.0->turftopic[pyro-ppl]) (0.16.0+cu121)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers<3.0.0,>=2.2.0->turftopic[pyro-ppl]) (3.8.1)
# Collecting sentencepiece (from sentence-transformers<3.0.0,>=2.2.0->turftopic[pyro-ppl])
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 16.3 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers<3.0.0,>=2.2.0->turftopic[pyro-ppl]) (0.20.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.1.0->turftopic[pyro-ppl]) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.1.0->turftopic[pyro-ppl]) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.1.0->turftopic[pyro-ppl]) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.1.0->turftopic[pyro-ppl]) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.1.0->turftopic[pyro-ppl]) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.1.0->turftopic[pyro-ppl]) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=2.1.0->turftopic[pyro-ppl]) (2.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers<3.0.0,>=2.2.0->turftopic[pyro-ppl]) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers<3.0.0,>=2.2.0->turftopic[pyro-ppl]) (6.0.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers<3.0.0,>=2.2.0->turftopic[pyro-ppl]) (23.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.6.0->turftopic[pyro-ppl]) (0.1.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers<3.0.0,>=2.2.0->turftopic[pyro-ppl]) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers<3.0.0,>=2.2.0->turftopic[pyro-ppl]) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers<3.0.0,>=2.2.0->turftopic[pyro-ppl]) (0.4.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch<3.0.0,>=2.1.0->turftopic[pyro-ppl]) (2.1.3)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers<3.0.0,>=2.2.0->turftopic[pyro-ppl]) (8.1.7)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch<3.0.0,>=2.1.0->turftopic[pyro-ppl]) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers<3.0.0,>=2.2.0->turftopic[pyro-ppl]) (9.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers<3.0.0,>=2.2.0->turftopic[pyro-ppl]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers<3.0.0,>=2.2.0->turftopic[pyro-ppl]) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers<3.0.0,>=2.2.0->turftopic[pyro-ppl]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers<3.0.0,>=2.2.0->turftopic[pyro-ppl]) (2023.11.17)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=421043e663df54d6eb177ab3b03ea36a8537da47b22fe43b2fe4e6681dc72ac6
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence-transformers
# Installing collected packages: sentencepiece, pyro-api, pyro-ppl, sentence-transformers, turftopic
# Successfully installed pyro-api-0.1.2 pyro-ppl-1.8.6 sentence-transformers-2.2.2 sentencepiece-0.1.99 turftopic-0.2.0

# %%
from sklearn.datasets import fetch_20newsgroups

newsgroups = fetch_20newsgroups(subset="all")
corpus = newsgroups.data

# %%
from sentence_transformers import SentenceTransformer

trf = SentenceTransformer("sentence-transformers/all-mpnet-base-v2")
embeddings = trf.encode(corpus)
# Out:
# .gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# train_script.py:   0%|          | 0.00/13.1k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
from turftopic import GMM

model = GMM(20, encoder=trf).fit(corpus,  embeddings=embeddings)
model.print_topics()
# Out:
# Output()
# [10:35:05] Term extraction done.                                                                          ]8;id=675876;file:///usr/local/lib/python3.10/dist-packages/turftopic/models/gmm.py\gmm.py]8;;\:]8;id=976123;file:///usr/local/lib/python3.10/dist-packages/turftopic/models/gmm.py#87\87]8;;\
# [10:38:22] Mixture model fitted.                                                                          ]8;id=670914;file:///usr/local/lib/python3.10/dist-packages/turftopic/models/gmm.py\gmm.py]8;;\:]8;id=211777;file:///usr/local/lib/python3.10/dist-packages/turftopic/models/gmm.py#90\90]8;;\
# [10:38:41] Model fitting done.                                                                            ]8;id=918564;file:///usr/local/lib/python3.10/dist-packages/turftopic/models/gmm.py\gmm.py]8;;\:]8;id=354599;file:///usr/local/lib/python3.10/dist-packages/turftopic/models/gmm.py#97\97]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ┏━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Topic ID ┃ Top 10 Words                                                                             ┃
# ┡━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │        0 │ window, server, widget, motif, dos, x11, xterm, windows, x11r5, display                  │
# ├──────────┼──────────────────────────────────────────────────────────────────────────────────────────┤
# │        1 │ sale, 00, shipping, offer, 50, condition, price, 10, sell, 1st                           │
# ├──────────┼──────────────────────────────────────────────────────────────────────────────────────────┤
# │        2 │ clipper, key, encryption, chip, escrow, keys, privacy, nsa, security, government         │
# ├──────────┼──────────────────────────────────────────────────────────────────────────────────────────┤
# │        3 │ team, hockey, game, nhl, play, season, 25, 55, pit, players                              │
# ├──────────┼──────────────────────────────────────────────────────────────────────────────────────────┤
# │        4 │ medical, health, disease, msg, cancer, patients, doctor, treatment, pitt, food           │
# ├──────────┼──────────────────────────────────────────────────────────────────────────────────────────┤
# │        5 │ god, atheists, atheism, religion, morality, atheist, objective, christian, moral, belief │
# ├──────────┼──────────────────────────────────────────────────────────────────────────────────────────┤
# │        6 │ baseball, game, players, team, year, hit, braves, games, runs, pitcher                   │
# ├──────────┼──────────────────────────────────────────────────────────────────────────────────────────┤
# │        7 │ israel, israeli, arab, jews, arabs, jewish, palestinian, palestinians, jake, israelis    │
# ├──────────┼──────────────────────────────────────────────────────────────────────────────────────────┤
# │        8 │ scsi, drive, ide, disk, drives, controller, hard, dos, floppy, disks                     │
# ├──────────┼──────────────────────────────────────────────────────────────────────────────────────────┤
# │        9 │ max, b8f, a86, cramer, 145, president, pl, 1d9, g9v, optilink                            │
# ├──────────┼──────────────────────────────────────────────────────────────────────────────────────────┤
# │       10 │ card, video, monitor, ram, board, mhz, modem, simms, bit, bus                            │
# ├──────────┼──────────────────────────────────────────────────────────────────────────────────────────┤
# │       11 │ armenian, turkish, armenians, armenia, turks, turkey, serdar, argic, genocide, muslim    │
# ├──────────┼──────────────────────────────────────────────────────────────────────────────────────────┤
# │       12 │ fbi, batf, koresh, waco, atf, compound, children, gas, survivors, bd                     │
# ├──────────┼──────────────────────────────────────────────────────────────────────────────────────────┤
# │       13 │ gun, guns, firearms, weapons, militia, amendment, control, crime, weapon, arms           │
# ├──────────┼──────────────────────────────────────────────────────────────────────────────────────────┤
# │       14 │ power, battery, circuit, wire, ground, problem, use, wiring, radar, voltage              │
# ├──────────┼──────────────────────────────────────────────────────────────────────────────────────────┤
# │       15 │ space, nasa, launch, orbit, moon, earth, shuttle, mission, henry, solar                  │
# ├──────────┼──────────────────────────────────────────────────────────────────────────────────────────┤
# │       16 │ jesus, god, christ, church, bible, sin, christian, christians, lord, paul                │
# ├──────────┼──────────────────────────────────────────────────────────────────────────────────────────┤
# │       17 │ car, bike, cars, dod, engine, bmw, ride, riding, oil, honda                              │
# ├──────────┼──────────────────────────────────────────────────────────────────────────────────────────┤
# │       18 │ file, image, windows, jpeg, files, graphics, ftp, max, db, format                        │
# ├──────────┼──────────────────────────────────────────────────────────────────────────────────────────┤
# │       19 │ espn, hockey, game, games, coverage, abc, baseball, sports, fans, devils                 │
# └──────────┴──────────────────────────────────────────────────────────────────────────────────────────┘

# %%
from turftopic import KeyNMF

model = KeyNMF(20, encoder=trf).fit(corpus,  embeddings=embeddings)
model.print_topics()
# Out:
# Output()
# [10:45:31] Keyword extraction done.                                                                   ]8;id=857944;file:///usr/local/lib/python3.10/dist-packages/turftopic/models/keynmf.py\keynmf.py]8;;\:]8;id=541247;file:///usr/local/lib/python3.10/dist-packages/turftopic/models/keynmf.py#218\218]8;;\
# [10:45:33] Model fiting done.                                                                         ]8;id=359663;file:///usr/local/lib/python3.10/dist-packages/turftopic/models/keynmf.py\keynmf.py]8;;\:]8;id=677096;file:///usr/local/lib/python3.10/dist-packages/turftopic/models/keynmf.py#224\224]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ┏━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Topic ID ┃ Top 10 Words                                                                               ┃
# ┡━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │        0 │ subject, organization, edu, lines, posting, university, host, nntp, mail, distribution     │
# ├──────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │        1 │ armenians, armenia, armenian, turkish, turks, genocide, soviet, turkey, azerbaijan, kurds  │
# ├──────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │        2 │ atheists, atheist, atheism, religion, god, belief, believe, religious, theists, beliefs    │
# ├──────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │        3 │ clipper, encryption, chip, nsa, security, wiretap, crypto, cryptography, escrow, privacy   │
# ├──────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │        4 │ israel, israeli, jews, israelis, jewish, palestinians, palestinian, arab, arabs, palestine │
# ├──────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │        5 │ windows, dos, microsoft, os, software, unix, program, ms, pc, programs                     │
# ├──────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │        6 │ hockey, nhl, bruins, leafs, playoff, playoffs, islanders, rangers, oilers, cup             │
# ├──────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │        7 │ gun, guns, firearms, weapons, police, handguns, firearm, handgun, nra, crime               │
# ├──────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │        8 │ sale, price, offer, interested, sell, shipping, posting, selling, prices, offers           │
# ├──────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │        9 │ car, cars, engine, ford, mustang, driving, drive, driver, v8, v6                           │
# ├──────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │       10 │ baseball, braves, pitching, mets, sox, phillies, yankees, cubs, pitchers, jays             │
# ├──────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │       11 │ christian, christians, christianity, bible, god, jesus, religion, sin, morality, christ    │
# ├──────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │       12 │ fbi, government, waco, atf, batf, survivors, davidians, clinton, burns, koresh             │
# ├──────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │       13 │ monitor, ram, scsi, computer, motherboard, card, cpu, hardware, mac, vga                   │
# ├──────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │       14 │ muslim, muslims, islam, bosnians, islamic, serbs, bosnia, bosnian, genocide, yugoslavia    │
# ├──────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │       15 │ article, subject, news, writes, gay, homosexuals, homosexual, opinions, people, morality   │
# ├──────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │       16 │ bike, motorcycle, ride, bikes, riding, motorcycles, honda, rider, bmw, harley              │
# ├──────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │       17 │ graphics, lines, 3d, software, vga, display, program, screen, images, card                 │
# ├──────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │       18 │ com, modem, fax, modems, mail, hp, port, phone, printer, ibm                               │
# ├──────────┼────────────────────────────────────────────────────────────────────────────────────────────┤
# │       19 │ nasa, space, orbit, astronomy, spacecraft, shuttle, moon, satellites, earth, sci           │
# └──────────┴────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
from turftopic import SemanticSignalSeparation

model = SemanticSignalSeparation(20, encoder=trf).fit(corpus,  embeddings=embeddings)
model.print_topics()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/decomposition/_fastica.py:542: FutureWarning: Starting in v1.3,
# whiten='unit-variance' will be used by default.
#   warnings.warn(
# Output()
# [10:45:37] Decomposition done.                                                                         ]8;id=67149;file:///usr/local/lib/python3.10/dist-packages/turftopic/models/decomp.py\decomp.py]8;;\:]8;id=876328;file:///usr/local/lib/python3.10/dist-packages/turftopic/models/decomp.py#69\69]8;;\
# [10:45:43] Term extraction done.                                                                       ]8;id=478474;file:///usr/local/lib/python3.10/dist-packages/turftopic/models/decomp.py\decomp.py]8;;\:]8;id=444635;file:///usr/local/lib/python3.10/dist-packages/turftopic/models/decomp.py#72\72]8;;\
# [10:45:52] Vocabulary encoded.                                                                         ]8;id=620821;file:///usr/local/lib/python3.10/dist-packages/turftopic/models/decomp.py\decomp.py]8;;\:]8;id=690811;file:///usr/local/lib/python3.10/dist-packages/turftopic/models/decomp.py#75\75]8;;\
#            Model fitting done.                                                                         ]8;id=390601;file:///usr/local/lib/python3.10/dist-packages/turftopic/models/decomp.py\decomp.py]8;;\:]8;id=441958;file:///usr/local/lib/python3.10/dist-packages/turftopic/models/decomp.py#79\79]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ┏━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Topic ID ┃ Top 10 Words                                                                                         ┃
# ┡━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │        0 │ homeopathy, poisoning, medical, resurection, malpractice, medicines, toxins, diseases, epilepsy,     │
# │          │ disease                                                                                              │
# ├──────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │        1 │ astronomy, spectrometer, astrophysics, biopsy, astrophysical, sightings, 1993apr29, 1993apr27,       │
# │          │ 1993apr26, transcaucasia                                                                             │
# ├──────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │        2 │ assembler, microcomputer, microprocessor, ieee, bee, bibliography, evangelicals, implementations,    │
# │          │ scicom, xhost                                                                                        │
# ├──────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │        3 │ directory, dir, directories, autoexec, folder, locker, buried, kuleuven, addressing, invoke          │
# ├──────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │        4 │ waco, explosives, fires, gunfire, wtc, napalm, fbi, firefight, watergate, flamed                     │
# ├──────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │        5 │ motorcycling, motorcyclist, motorcycle, motorcyclists, motorcycles, biker, bike, bikers, handlebars, │
# │          │ harleys                                                                                              │
# ├──────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │        6 │ palestine, palestineans, palestinean, palestinians, palestinian, aviv, israelis, haifa, knesset,     │
# │          │ zionism                                                                                              │
# ├──────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │        7 │ xcreatewindow, xtwindow, xtappaddtimeout, xopendisplay, x11, xsession, xremote, xwindows, x11r3,     │
# │          │ xmodmap                                                                                              │
# ├──────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │        8 │ tiff, bitmaps, textures, bitmap, adobe, imagemagick, graphics, texture, pgf, pixmaps                 │
# ├──────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │        9 │ successor, fabrication, lachman, bio, yeast, serge, galen, macmillan, surgical, biochem              │
# ├──────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       10 │ complaint, warnings, misinformation, disinformation, revisionism, newsletter, censorship,            │
# │          │ editorials, complaints, discrimination                                                               │
# ├──────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       11 │ christianity, theology, scripture, theological, agnosticism, faiths, christians, unbelievers,        │
# │          │ scriptural, pantheism                                                                                │
# ├──────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       12 │ constitutionally, nra, handguns, constitutional, legalization, freedoms, prohibition, legalizing,    │
# │          │ guns, firearms                                                                                       │
# ├──────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       13 │ macworld, macuser, powerpc, macweek, applelink, mac, powerbook, monk, waving, macc                   │
# ├──────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       14 │ benchmarks, scientifically, accelerators, physicists, autobahn, speedometer, aeronautics,            │
# │          │ aerodynamics, advances, astrophysics                                                                 │
# ├──────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       15 │ encryption, cryptophones, encryptions, cryptography, eavesdropping, cryptology, cryptosystems,       │
# │          │ cryptographic, cryptographically, crypt                                                              │
# ├──────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       16 │ synagogues, zion, ministry, lds, milwaukee, congregations, congregation, brigham, affiliates, moses  │
# ├──────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       17 │ caller, modem, transcript, codec, voicemail, fax, 806, 802, 866, 808                                 │
# ├──────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       18 │ fairbanks, soyuz, quebec, rusnews, mainland, arctic, tsn, alberta, nanaimo, vancouver                │
# ├──────────┼──────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       19 │ harddrive, hdd, harddisk, seagate, ssd, disk, megadrive, disks, smartdrive, prodrive                 │
# └──────────┴──────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
from turftopic import ClusteringTopicModel

model = ClusteringTopicModel(encoder=trf).fit(corpus,  embeddings=embeddings)
model.print_topics()
# Out:
# Output()
# [10:45:57] Term extraction done.                                                                     ]8;id=661951;file:///usr/local/lib/python3.10/dist-packages/turftopic/models/cluster.py\cluster.py]8;;\:]8;id=427187;file:///usr/local/lib/python3.10/dist-packages/turftopic/models/cluster.py#100\100]8;;\
# [10:49:24] Dimensionality reduction done.                                                            ]8;id=186139;file:///usr/local/lib/python3.10/dist-packages/turftopic/models/cluster.py\cluster.py]8;;\:]8;id=522195;file:///usr/local/lib/python3.10/dist-packages/turftopic/models/cluster.py#106\106]8;;\
# [10:49:53] Clustering done.                                                                          ]8;id=428952;file:///usr/local/lib/python3.10/dist-packages/turftopic/models/cluster.py\cluster.py]8;;\:]8;id=700451;file:///usr/local/lib/python3.10/dist-packages/turftopic/models/cluster.py#110\110]8;;\
#            Model fitting done.                                                                       ]8;id=413248;file:///usr/local/lib/python3.10/dist-packages/turftopic/models/cluster.py\cluster.py]8;;\:]8;id=730360;file:///usr/local/lib/python3.10/dist-packages/turftopic/models/cluster.py#128\128]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ┏━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Topic ID ┃ Top 10 Words                                                                                      ┃
# ┡━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │       -1 │ max, file, use, host, good, nntp, does, ca, new, cs                                               │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │        0 │ sabres, buffalo, fuhr, bruins, boston, game, fans, playoff, lafontaine, penguins                  │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │        1 │ vs, winner, predictions, pens, chi, bos, cal, cup, win, stanley                                   │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │        2 │ leafs, wings, probert, toronto, gilmour, detroit, leaf, burns, potvin, maynard                    │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │        3 │ ahl, hockey, nhl, team, franchise, milwaukee, minnesota, stars, clarkson, city                    │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │        4 │ 25, pit, pts, det, la, period, bos, tor, gm, 11                                                   │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │        5 │ finland, sweden, ericsson, wc, czech, april, canada, switzerland, ufsa, etxonss                   │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │        6 │ ulf, player, shot, game, huot, penalty, players, penalties, foul, hockey                          │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │        7 │ nhl, players, hockey, europeans, league, rauser, teams, names, european, canadian                 │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │        8 │ mask, goalie, gtd597a, votes, hrivnak, masks, gatech, prism, hammerl, buffalo                     │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │        9 │ cherry, coach, cmu, gilmour, madden, game, don, allan, hockey, andrew                             │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │

# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       48 │ lens, camera, camcorder, rupin, dang, goldberg, zoom, nikon, sale, dartmouth                      │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       49 │ games, sega, genesis, snes, sale, cd, game, trade, bach, lancaster                                │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       50 │ 486, motherboard, bus, 486dx, 50, 386dx, mhz, 486dx2, amd, cpu                                    │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       51 │ gateway, zeos, service, price, computers, order, monitor, tech, mail, 66v                         │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       52 │ simms, simm, 256k, ram, memory, meg, pin, dram, 80ns, 72                                          │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       53 │ cd, sleeve, sale, cds, picture, 45, jazz, tapes, ppd, contains                                    │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       54 │ card, board, connector, ethernet, pin, motherboard, louisville, pins, connectors, help            │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       55 │ tempest, subliminal, holland, northeastern, tv, cam, colostate, pick, utsa, monitor               │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       56 │ sale, room, summer, dryer, kitchen, bedroom, house, wanted, art, compu                            │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       57 │ ticket, hiram, hotel, package, airline, vacation, tickets, koutd, vouchers, nights                │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       58 │ ide, drive, controller, scsi, slave, drives, seagate, master, cmos, hd                            │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       59 │ scsi, ide, bus, controller, isa, dma, sec, drive, drives, transfer                                │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       60 │ cd, rom, toshiba, cd300, apple, cdrom, drive, 3401, nec, audio                                    │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       61 │ umcc, beeps, error, mac, mats, memory, startup, rebooting, pilon, quadra                          │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       62 │ monitor, screen, video, problem, sync, apple, monitors, 610, lcd, colors                          │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       63 │ nanao, monitors, monitor, nec, 17, trinitron, viewsonic, inches, tube, 5fg                        │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       64 │ drivers, driver, card, trident, video, windows, ftp, svga, latest, ati                            │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       65 │ ati, drivers, ultra, card, gateway, 24x, 1280x1024, windows, monitor, mode                        │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       66 │ diamond, stealth, drivers, card, speedstar, hartmann, video, ibm, lance, doug                     │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       67 │ mode, vga, vesa, svga, 256, modes, video, memory, graphics, bios                                  │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       68 │ eisa, isa, vlb, bus, motherboard, dma, vesa, cards, card, video                                   │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       69 │ phone, hook, number, line, umass, ecs, alee, al, dial, led                                        │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       70 │ modem, modems, fax, courier, baud, sportster, 2400, 9600, external, midwest                       │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       71 │ irq, port, modem, interrupt, com3, com4, ports, card, com1, com2                                  │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       72 │ deskjet, bubblejet, ink, printer, hp, printers, canon, laser, bj, 500                             │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       73 │ gopher, search, ftp, client, sites, usgs, database, site, welch, software                         │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       74 │ split, graphics, group, newsgroup, engin, aspects, comp, umich, tdawson, groups                   │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       75 │ phigs, 3d, graphics, library, package, shading, hidden, wireframe, pex, carpenter                 │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       76 │ image, processing, tools, analysis, tool, plotting, package, tar, data, user                      │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       77 │ postscript, ghostscript, ghostview, files, eps, dsc, page, ow, compliant, tufts                   │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       78 │ gif, linux, format, bmp, files, convert, gifs, cview, program, viewer                             │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       79 │ 0d, _o, cx, c_, 145, s6, 6um, 6t, 6ei, 0g                                                         │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       80 │ books, guide, 00, machines, precision, comments, algebra, contact, list, book                     │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       81 │ motif, openwindows, xview, olit, x11, ftp, usr, toolkit, gui, look                                │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       82 │ window, manager, position, parcplace, geometry, title, berlin, boulder, ethan, nl                 │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       83 │ expose, window, event, buzz, whaley, handler, xcopyarea, events, item, mapped                     │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       84 │ colormap, visual, colormaps, colors, window, dpy, badmatch, color, default, depth                 │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       85 │ xv, escaped, endif, define, sussex, bradley, 00, echo, defined, julian                            │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       86 │ keyboard, key, keys, accelerators, keycode, ctrl, shift, emacs, xmodmap, modifiers                │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       87 │ cursor, xterm, blinking, keymap, taylor, string, bold, cursors, font, emu                         │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       88 │ font, fonts, truetype, atm, tt, characters, windows, character, printer, type                     │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       89 │ nt, windows, os, run, win, dos, gupta, multi, apps, beta                                          │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       90 │ microsoft, os, challenge, supporters, windows, ms, dos, apps, uc, duke                            │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       91 │ dos, allocation, linked, stacker, windows, disk, gfx, cross, dos6, dblspace                       │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       92 │ mouse, jumpy, motion, driver, byu, smoothly, stuttgart, ecktons, eckton, jump                     │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       93 │ polygon, polygons, ___, algorithm, routine, bezier, curves, fast, concave, 3d                     │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       94 │ mac, 800, macintosh, sys, comp, files, disk, software, faq, ftp                                   │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       95 │ 3do, quicktime, playback, 68070, mcmains, ricardo, unt, fps, rumours, rchland                     │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       96 │ data, image, images, ftp, gif, grass, ics, incoming, available, pci                               │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       97 │ xputimage, shared, server, memory, animation, cam, pixmaps, sunview, ast, shm                     │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       98 │ space, launch, satellite, commercial, satellites, market, nasa, aerospace, launches, term         │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │       99 │ dc, shuttle, sdio, boeing, ssto, flight, space, vehicle, orbit, aircraft                          │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │      100 │ station, redesign, space, nasa, ssf, option, shuttle, jsc, launch, alaska                         │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │      101 │ moon, lunar, billion, prize, alaska, ke4zv, theporch, henry, raider, cost                         │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │      102 │ sky, vandalizing, rights, nicho, night, light, cso, pollution, krumins, uiuc                      │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │      103 │ hst, mission, servicing, shuttle, boost, arrays, oms, digex, orbit, pat                           │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │      104 │ duo, powerbook, portable, dock, apple, pb100, pb, mac, dartmouth, powerbooks                      │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │      105 │ energy, cooling, nuclear, towers, water, centaur, plants, proton, steam, uranium                  │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │      106 │ rocks, teenagers, warning, kids, overpass, triumf, erich, read, violence, boeing                  │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │      107 │ militia, amendment, arms, regulated, bear, constitution, right, second, infringed, sentence       │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │      108 │ tax, taxes, income, vat, deficit, plant, court, atlantic, property, boomer                        │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │      109 │ br, isc, government, thor, steveh, libertarians, hendricks, libertarian, libertarianism, limiting │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │      110 │ freedom, forged, colorado, virginia, beyer, ucla, ted, ab4z, columbia, speach                     │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │      111 │ king, nc, adjective, kyle, verdict, rodney, kkopp, cramm, koppenhoefer, trial                     │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │      112 │ president, mr, myers, ms, jobs, going, clinton, secretary, administration, package                │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │      113 │ reno, janet, children, waco, madman, hostage, provoked, cleveland, killed, koresh                 │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │      114 │ atf, dividian, ranch, survivors, burns, fbi, irvine, stove, brent, uxh                            │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │      115 │ gas, tear, unb, cs, jupiter, toxic, riddle, children, convex, chamber                             │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │      116 │ koresh, sandvik, utarlg, kent, uta, stephen, sbc, davidians, children, backing                    │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │      117 │ cruel, punishment, penalty, death, capital, keith, atheists, caltech, innocent, murder            │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │      118 │ atheism, genocide, caused, atheist, frank, theists, stalin, atheists, livesey, dwyer              │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │      119 │ truth, arrogance, absolute, absolutes, christians, arrogant, darren, scripture, belief, beliefs   │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │      120 │ objective, morality, frank, values, moral, d012s658, dwyer, 2000, halat, mathew                   │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │      121 │ moral, keith, morality, livesey, caltech, natural, animals, solntze, schneider, wpd               │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │      122 │ resurrection, jesus, tomb, rise, christ, disciples, body, ata, evidence, judas                    │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │

# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │      160 │ muslims, muslim, serbs, croats, bosnian, yugoslavia, josip, bosnians, croatia, islam              │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │      161 │ battery, batteries, concrete, acid, lead, discharge, temperature, floor, dirt, ocis               │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │      162 │ random, key, passwords, fifth, security, bits, amendment, compelled, password, mitre              │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │      163 │ copy, protected, protection, disks, sehari, program, disk, software, registration, user           │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │      164 │ armenian, armenians, turkish, armenia, serdar, argic, genocide, soviet, azerbaijan, turks         │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┤
# │      165 │ greek, greece, greeks, turkish, turks, turkey, cyprus, minority, jews, ottoman                    │
# └──────────┴───────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
from turftopic import AutoEncodingTopicModel

model = AutoEncodingTopicModel(20, encoder=trf).fit(corpus,  embeddings=embeddings)
model.print_topics()
# Out:
# Output()
# [10:49:59] Term extraction done.                                                                         ]8;id=425448;file:///usr/local/lib/python3.10/dist-packages/turftopic/models/ctm.py\ctm.py]8;;\:]8;id=622066;file:///usr/local/lib/python3.10/dist-packages/turftopic/models/ctm.py#198\198]8;;\
# [10:55:42] Model fitting done.                                                                           ]8;id=42450;file:///usr/local/lib/python3.10/dist-packages/turftopic/models/ctm.py\ctm.py]8;;\:]8;id=271493;file:///usr/local/lib/python3.10/dist-packages/turftopic/models/ctm.py#251\251]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ┏━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Topic ID ┃ Top 10 Words                                                                              ┃
# ┡━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │        0 │ bike, bmw, motorcycle, engine, dod, cars, riding, ride, car, motorcycles                  │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────┤
# │        1 │ year, hit, better, runs, big, average, ball, baseball, pitcher, winfield                  │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────┤
# │        2 │ space, nasa, research, center, power, years, 1993, earth, national, low                   │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────┤
# │        3 │ alaska, zoo, aurora, nsmca, henry, prb, ti, zoology, digex, geb                           │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────┤
# │        4 │ gizwt, shields, bury, daughters, 10th, 16m, u3l, edited, promise, daily                   │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────┤
# │        5 │ key, clipper, encryption, chip, pgp, keys, phone, security, des, algorithm                │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────┤
# │        6 │ atf, batf, koresh, fbi, waco, bd, survivors, stratus, compound, sw                        │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────┤
# │        7 │ 25, 00, 30, 17, 27, 10, 50, 15, 20, 75                                                    │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────┤
# │        8 │ god, jesus, church, bible, word, life, christians, christian, man, paul                   │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────┤
# │        9 │ tu, x11r5, cursor, width, event, lib, button, xdm, dresden, displayed                     │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────┤
# │       10 │ drive, scsi, bus, card, board, ide, drives, apple, 486, video                             │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────┤
# │       11 │ cup, wings, espn, stanley, penalties, pens, devils, penguins, buffalo, abc                │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────┤
# │       12 │ world, war, uucp, jewish, history, jews, armenians, armenian, israel, armenia             │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────┤
# │       13 │ edu, software, file, windows, use, com, files, mail, dos, graphics                        │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────┤
# │       14 │ ax, didn, team, don, said, game, play, hockey, did, went                                  │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────┤
# │       15 │ ax, 0d, db, _o, cx, c_, mf, mj, 6t, 145                                                   │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────┤
# │       16 │ forsale, brand, offer, sale, selling, manuals, condition, dakota, asking, vcr             │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────┤
# │       17 │ appreciate, pcx, searching, sg, polygon, advance, gizwt, anybody, presentation, carpenter │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────┤
# │       18 │ evidence, optilink, jon, cramer, morality, keith, frank, atheism, atheists, moral         │
# ├──────────┼───────────────────────────────────────────────────────────────────────────────────────────┤
# │       19 │ people, think, don, just, right, like, gun, know, going, ll                               │
# └──────────┴───────────────────────────────────────────────────────────────────────────────────────────┘
